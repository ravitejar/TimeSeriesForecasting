# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
import statsmodels.tsa as sm1
from pandas.tools.plotting import autocorrelation_plot
from scipy import stats
from statsmodels.graphics.api import qqplot
from statsmodels.tsa.arima_process import arma_generate_sample

from datetime import datetime
from sklearn.cross_validation import train_test_split,StratifiedKFold,KFold,cross_val_score
from sklearn import cross_validation
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve, auc, classification_report,r2_score
from scipy import interp
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier,export_graphviz
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier  #GBM algorithm
from sklearn import cross_validation, metrics   #Additional scklearn functions
from sklearn.grid_search import GridSearchCV   #Perforing grid search
from matplotlib.pylab import rcParams
from __future__ import division

# %%
sales=pd.read_excel('filter_for_final_ts.xlsx',index='Date')

# %%
sales.head()
# Out:
#    Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      6 2012-10-21        72.34       3.506    6827.59      53.07        NaN
# 1      2 2012-10-21        69.79       3.506    6152.59     129.77     200.00
# 2     11 2012-10-21        74.26       3.506    4115.64     147.27     153.00
# 3     14 2012-10-21        58.85       3.882    9258.41      99.19     117.84
# 4      5 2012-10-21        71.70       3.506    1547.61       1.74        NaN
#
#    MarkDown4  MarkDown5         CPI  Unemployment  Weekly_Sales
# 0     319.25    1881.27  225.068625         5.329    1431426.34
# 1     272.29    2924.15  223.078337         6.170    1834458.35
# 2    1060.90    3936.20  226.987364         6.034    1200729.45
# 3    1489.28    1433.31  192.308899         8.667    1704357.62
# 4     133.31     598.74  224.037814         5.422     319550.77

# %%
sales.shape
# Out:
# (6435, 12)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6435 entries, 0 to 6434
# Data columns (total 12 columns):
# Store           6435 non-null int64
# Date            6435 non-null datetime64[ns]
# Temperature     6435 non-null float64
# Fuel_Price      6435 non-null float64
# MarkDown1       2280 non-null float64
# MarkDown2       1637 non-null float64
# MarkDown3       2046 non-null float64
# MarkDown4       1965 non-null float64
# MarkDown5       2295 non-null float64
# CPI             6435 non-null float64
# Unemployment    6435 non-null float64
# Weekly_Sales    6435 non-null float64
# dtypes: datetime64[ns](1), float64(10), int64(1)
# memory usage: 653.6 KB

# %%
sales.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4155
# MarkDown2       4798
# MarkDown3       4389
# MarkDown4       4470
# MarkDown5       4140
# CPI                0
# Unemployment       0
# Weekly_Sales       0
# dtype: int64

# %%
sales.fillna(value=0,axis=1,inplace=True)

# %%
sales["Date"] = (pd.to_datetime(sales["Date"], format="%d-%m-%Y"))

# %%
sales['Day_of_Month']=sales["Date"].apply(lambda x: x.day)

# %%
sales['Month']=sales["Date"].apply(lambda x: x.month)

# %%
sales['DayOfYear']=sales["Date"].apply(lambda x: x.dayofyear)

# %%
sales['WeekOfYear']=sales["Date"].apply(lambda x: x.weekofyear)

# %%
sales['Quarter']=sales["Date"].apply(lambda x: x.quarter)

# %%
sales['WeekDay']=sales["Date"].apply(lambda x: x.weekday())

# %%
sales['DayCount']=sales["Date"].apply(lambda x: x.toordinal())

# %%
sales.head()
# Out:
#    Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      6 2012-10-21        72.34       3.506    6827.59      53.07       0.00
# 1      2 2012-10-21        69.79       3.506    6152.59     129.77     200.00
# 2     11 2012-10-21        74.26       3.506    4115.64     147.27     153.00
# 3     14 2012-10-21        58.85       3.882    9258.41      99.19     117.84
# 4      5 2012-10-21        71.70       3.506    1547.61       1.74       0.00
#
#    MarkDown4  MarkDown5         CPI  Unemployment  Weekly_Sales  Day_of_Month  \
# 0     319.25    1881.27  225.068625         5.329    1431426.34            21
# 1     272.29    2924.15  223.078337         6.170    1834458.35            21
# 2    1060.90    3936.20  226.987364         6.034    1200729.45            21
# 3    1489.28    1433.31  192.308899         8.667    1704357.62            21
# 4     133.31     598.74  224.037814         5.422     319550.77            21
#
#    Month  DayOfYear  WeekOfYear  Quarter  WeekDay  DayCount
# 0     10        295          42        4        6    734797
# 1     10        295          42        4        6    734797
# 2     10        295          42        4        6    734797
# 3     10        295          42        4        6    734797
# 4     10        295          42        4        6    734797

# %%
sales.sort(columns=['Store','Date'],inplace=True)
# Out:
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
sales.Date.apply(lambda x:x-pd.DateOffset(weeks=53)).head()
# Out:
# 6429   2009-01-25
# 6359   2009-02-01
# 6331   2009-02-08
# 6279   2009-02-15
# 6219   2009-02-22
# Name: Date, dtype: datetime64[ns]

# %%
sales.Date.head()
# Out:
# 6429   2010-01-31
# 6359   2010-02-07
# 6331   2010-02-14
# 6279   2010-02-21
# 6219   2010-02-28
# Name: Date, dtype: datetime64[ns]

# %%
sales.columns
# Out:
# Index([       u'Store',         u'Date',  u'Temperature',   u'Fuel_Price',
#           u'MarkDown1',    u'MarkDown2',    u'MarkDown3',    u'MarkDown4',
#           u'MarkDown5',          u'CPI', u'Unemployment', u'Weekly_Sales',
#        u'Day_of_Month',        u'Month',    u'DayOfYear',   u'WeekOfYear',
#             u'Quarter',      u'WeekDay',     u'DayCount'],
#       dtype='object')

# %%
sales.ix[(sales.Date=='2011-10-16')&(sales.Store==6),:]
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 2419      6 2011-10-16        68.53       3.353          0          0
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  Weekly_Sales  \
# 2419          0          0          0  219.074017         6.551    1417922.37
#
#       Day_of_Month  Month  DayOfYear  WeekOfYear  Quarter  WeekDay  DayCount
# 2419            16     10        289          41        4        6    734426

# %%
store=sales[sales.Store==1]
store['Date'] =pd.to_datetime(store.Date)
store.set_index('Date',inplace=True)
store['Weekly_Sales_prev_yr']=store['Weekly_Sales'].shift(53)
store.reset_index(inplace=True)
x=pd.concat((sales,store),join='inner',axis=1)['Weekly_Sales_prev_yr']

for i in range(2,145):
    store=sales[sales.Store==i]
    store['Date'] =pd.to_datetime(store.Date)
    store.set_index('Date',inplace=True)
    store['Weekly_Sales_prev_yr']=store['Weekly_Sales'].shift(53)
    store.reset_index(inplace=True)
    x=x.append(pd.concat((sales,store),join='inner',axis=1)['Weekly_Sales_prev_yr'])
# Out:
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
store=sales[sales.Store==1]
store['Date'] =pd.to_datetime(store.Date)
store.set_index('Date',inplace=True)
store['Weekly_Sales_prev_yr_1']=store['Weekly_Sales'].shift(52)
store.reset_index(inplace=True)
x1=pd.concat((sales,store),join='inner',axis=1)['Weekly_Sales_prev_yr_1']

for i in range(2,145):
    store=sales[sales.Store==i]
    store['Date'] =pd.to_datetime(store.Date)
    store.set_index('Date',inplace=True)
    store['Weekly_Sales_prev_yr_1']=store['Weekly_Sales'].shift(51)
    store.reset_index(inplace=True)
    x1=x1.append(pd.concat((sales,store),join='inner',axis=1)['Weekly_Sales_prev_yr_1'])
# Out:
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
store=sales[sales.Store==1]
store['Date'] =pd.to_datetime(store.Date)
store.set_index('Date',inplace=True)
store['Weekly_Sales_prev_week']=store['Weekly_Sales'].shift(1)
store.reset_index(inplace=True)
x2=pd.concat((sales,store),join='inner',axis=1)['Weekly_Sales_prev_week']

for i in range(2,145):
    store=sales[sales.Store==i]
    store['Date'] =pd.to_datetime(store.Date)
    store.set_index('Date',inplace=True)
    store['Weekly_Sales_prev_week']=store['Weekly_Sales'].shift(1)
    store.reset_index(inplace=True)
    x2=x2.append(pd.concat((sales,store),join='inner',axis=1)['Weekly_Sales_prev_week'])
# Out:
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\raviteja\Anaconda2\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sales.reset_index(inplace=True)

# %%
sales.head()
# Out:
#    index  Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0   6429      1 2010-01-31        42.31       2.572          0          0
# 1   6359      1 2010-02-07        38.51       2.548          0          0
# 2   6331      1 2010-02-14        39.93       2.514          0          0
# 3   6279      1 2010-02-21        46.63       2.561          0          0
# 4   6219      1 2010-02-28        46.50       2.625          0          0
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  Weekly_Sales  \
# 0          0          0          0  211.096358         8.106    1643690.90
# 1          0          0          0  211.242170         8.106    1641957.44
# 2          0          0          0  211.289143         8.106    1611968.17
# 3          0          0          0  211.319643         8.106    1409727.59
# 4          0          0          0  211.350143         8.106    1554806.68
#
#    Day_of_Month  Month  DayOfYear  WeekOfYear  Quarter  WeekDay  DayCount
# 0            31      1         31           4        1        6    733803
# 1             7      2         38           5        1        6    733810
# 2            14      2         45           6        1        6    733817
# 3            21      2         52           7        1        6    733824
# 4            28      2         59           8        1        6    733831

# %%
sales.shape
# Out:
# (6435, 20)

# %%
x=x.reset_index()['Weekly_Sales_prev_yr']

# %%
x1=x1.reset_index()['Weekly_Sales_prev_yr_1']

# %%
x2=x2.reset_index()['Weekly_Sales_prev_week']

# %%
sales = sales.join(x)

# %%
sales.head()
# Out:
#    index  Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0   6429      1 2010-01-31        42.31       2.572          0          0
# 1   6359      1 2010-02-07        38.51       2.548          0          0
# 2   6331      1 2010-02-14        39.93       2.514          0          0
# 3   6279      1 2010-02-21        46.63       2.561          0          0
# 4   6219      1 2010-02-28        46.50       2.625          0          0
#
#    MarkDown3  MarkDown4  MarkDown5          ...           Unemployment  \
# 0          0          0          0          ...                  8.106
# 1          0          0          0          ...                  8.106
# 2          0          0          0          ...                  8.106
# 3          0          0          0          ...                  8.106
# 4          0          0          0          ...                  8.106
#
#    Weekly_Sales  Day_of_Month  Month  DayOfYear  WeekOfYear  Quarter  WeekDay  \
# 0    1643690.90            31      1         31           4        1        6
# 1    1641957.44             7      2         38           5        1        6
# 2    1611968.17            14      2         45           6        1        6
# 3    1409727.59            21      2         52           7        1        6
# 4    1554806.68            28      2         59           8        1        6
#
#    DayCount  Weekly_Sales_prev_yr
# 0    733803                   NaN
# 1    733810                   NaN
# 2    733817                   NaN
# 3    733824                   NaN
# 4    733831                   NaN
#
# [5 rows x 21 columns]

# %%
sales = sales.join(x1)
sales = sales.join(x2)

# %%
sales.shape
# Out:
# (6435, 23)

# %%
sales.head()
# Out:
#    index  Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0   6429      1 2010-01-31        42.31       2.572          0          0
# 1   6359      1 2010-02-07        38.51       2.548          0          0
# 2   6331      1 2010-02-14        39.93       2.514          0          0
# 3   6279      1 2010-02-21        46.63       2.561          0          0
# 4   6219      1 2010-02-28        46.50       2.625          0          0
#
#    MarkDown3  MarkDown4  MarkDown5           ...            Day_of_Month  \
# 0          0          0          0           ...                      31
# 1          0          0          0           ...                       7
# 2          0          0          0           ...                      14
# 3          0          0          0           ...                      21
# 4          0          0          0           ...                      28
#
#    Month  DayOfYear  WeekOfYear  Quarter  WeekDay  DayCount  \
# 0      1         31           4        1        6    733803
# 1      2         38           5        1        6    733810
# 2      2         45           6        1        6    733817
# 3      2         52           7        1        6    733824
# 4      2         59           8        1        6    733831
#
#    Weekly_Sales_prev_yr  Weekly_Sales_prev_yr_1  Weekly_Sales_prev_week
# 0                   NaN                     NaN                     NaN
# 1                   NaN                     NaN              1643690.90
# 2                   NaN                     NaN              1641957.44
# 3                   NaN                     NaN              1611968.17
# 4                   NaN                     NaN              1409727.59
#
# [5 rows x 23 columns]

# %%
sales.Weekly_Sales_prev_yr.isnull().sum()
# Out:
# 2385

# %%
sales.head()
# Out:
#    index  Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0   6429      1 2010-01-31        42.31       2.572          0          0
# 1   6359      1 2010-02-07        38.51       2.548          0          0
# 2   6331      1 2010-02-14        39.93       2.514          0          0
# 3   6279      1 2010-02-21        46.63       2.561          0          0
# 4   6219      1 2010-02-28        46.50       2.625          0          0
#
#    MarkDown3  MarkDown4  MarkDown5           ...            Day_of_Month  \
# 0          0          0          0           ...                      31
# 1          0          0          0           ...                       7
# 2          0          0          0           ...                      14
# 3          0          0          0           ...                      21
# 4          0          0          0           ...                      28
#
#    Month  DayOfYear  WeekOfYear  Quarter  WeekDay  DayCount  \
# 0      1         31           4        1        6    733803
# 1      2         38           5        1        6    733810
# 2      2         45           6        1        6    733817
# 3      2         52           7        1        6    733824
# 4      2         59           8        1        6    733831
#
#    Weekly_Sales_prev_yr  Weekly_Sales_prev_yr_1  Weekly_Sales_prev_week
# 0                   NaN                     NaN                     NaN
# 1                   NaN                     NaN              1643690.90
# 2                   NaN                     NaN              1641957.44
# 3                   NaN                     NaN              1611968.17
# 4                   NaN                     NaN              1409727.59
#
# [5 rows x 23 columns]

# %%
sales.shape
# Out:
# (6435, 23)

# %%
sales.dropna(inplace=True)

# %%
sales.columns
# Out:
# Index([                 u'index',                  u'Store',
#                          u'Date',            u'Temperature',
#                    u'Fuel_Price',              u'MarkDown1',
#                     u'MarkDown2',              u'MarkDown3',
#                     u'MarkDown4',              u'MarkDown5',
#                           u'CPI',           u'Unemployment',
#                  u'Weekly_Sales',           u'Day_of_Month',
#                         u'Month',              u'DayOfYear',
#                    u'WeekOfYear',                u'Quarter',
#                       u'WeekDay',               u'DayCount',
#          u'Weekly_Sales_prev_yr', u'Weekly_Sales_prev_yr_1',
#        u'Weekly_Sales_prev_week'],
#       dtype='object')

# %%
sales.head()
# Out:
#     index  Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 53   4038      1 2011-02-06        36.39       3.022          0          0
# 54   3974      1 2011-02-13        57.36       3.045          0          0
# 55   3919      1 2011-02-20        62.90       3.065          0          0
# 56   3901      1 2011-02-27        59.58       3.288          0          0
# 57   3837      1 2011-03-06        53.56       3.459          0          0
#
#     MarkDown3  MarkDown4  MarkDown5           ...            Day_of_Month  \
# 53          0          0          0           ...                       6
# 54          0          0          0           ...                      13
# 55          0          0          0           ...                      20
# 56          0          0          0           ...                      27
# 57          0          0          0           ...                       6
#
#     Month  DayOfYear  WeekOfYear  Quarter  WeekDay  DayCount  \
# 53      2         37           5        1        6    734174
# 54      2         44           6        1        6    734181
# 55      2         51           7        1        6    734188
# 56      2         58           8        1        6    734195
# 57      3         65           9        1        6    734202
#
#     Weekly_Sales_prev_yr  Weekly_Sales_prev_yr_1  Weekly_Sales_prev_week
# 53            1643690.90              1641957.44              1606629.58
# 54            1641957.44              1611968.17              1649614.93
# 55            1611968.17              1409727.59              1686842.78
# 56            1409727.59              1554806.68              1456800.28
# 57            1554806.68              1439541.59              1636263.41
#
# [5 rows x 23 columns]

# %%
sales=sales[[u'Store',u'Temperature',u'Fuel_Price',u'MarkDown1',u'MarkDown2',u'MarkDown3',u'MarkDown4',u'MarkDown5',u'CPI',
             u'Unemployment',u'Day_of_Month',u'Month',u'DayOfYear',u'WeekOfYear',u'Quarter',u'WeekDay',u'DayCount',
             u'Weekly_Sales_prev_yr',u'Weekly_Sales_prev_yr_1','Weekly_Sales_prev_week',u'Weekly_Sales']]

# %% [markdown]
# # Model 1: Gradient Boosting Regression

# %%
x=sales.drop(['Weekly_Sales'],axis=1)
y=sales.Weekly_Sales
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

# %%
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

# %%
params = {'n_estimators': 500, 'max_depth': 10}
clf = ensemble.GradientBoostingRegressor(**params)

# %%
clf.fit(X_train, y_train)
mse = mean_squared_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % mse)
# Out:
# MSE: 8097731045.8173

# %%
sales['GBM_Pred']=clf.predict(x)

# %%
sales.to_csv('sales.csv')

# %%
clf.score(X_train, y_train)
# Out:
# 0.99999999938573314

# %%
clf.score(X_test, y_test)
# Out:
# 0.97516793744958374

# %%
r2_score(y,clf.predict(x))
# Out:
# 0.98959553833380387

# %%
sales.head()
# Out:
#     Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 53      1        36.39       3.022          0          0          0
# 54      1        57.36       3.045          0          0          0
# 55      1        62.90       3.065          0          0          0
# 56      1        59.58       3.288          0          0          0
# 57      1        53.56       3.459          0          0          0
#
#     MarkDown4  MarkDown5         CPI  Unemployment      ...       Month  \
# 53          0          0  212.936705         7.742      ...           2
# 54          0          0  213.247885         7.742      ...           2
# 55          0          0  213.535609         7.742      ...           2
# 56          0          0  213.823333         7.742      ...           2
# 57          0          0  214.111056         7.742      ...           3
#
#     DayOfYear  WeekOfYear  Quarter  WeekDay  DayCount  Weekly_Sales_prev_yr  \
# 53         37           5        1        6    734174            1643690.90
# 54         44           6        1        6    734181            1641957.44
# 55         51           7        1        6    734188            1611968.17
# 56         58           8        1        6    734195            1409727.59
# 57         65           9        1        6    734202            1554806.68
#
#     Weekly_Sales_prev_yr_1  Weekly_Sales_prev_week  Weekly_Sales
# 53              1641957.44              1606629.58    1649614.93
# 54              1611968.17              1649614.93    1686842.78
# 55              1409727.59              1686842.78    1456800.28
# 56              1554806.68              1456800.28    1636263.41
# 57              1439541.59              1636263.41    1553191.63
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(20,10))
feat_imp = pd.Series(clf.feature_importances_, X_test.columns).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Feature Importances')
plt.ylabel('Feature Importance Score')

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
rmse(clf.predict(x),sales['Weekly_Sales'])
# Out:
# 57689.627169187865

# %%
clf.predict(x)
# Out:
# array([ 1679431.19604683,  1686841.06883443,  1456798.39018452, ...,
#          730228.41687327,   718111.53496415,   760281.74620169])

# %%
sales['Weekly_Sales']
# Out:
# 53      1649614.93
# 54      1686842.78
# 55      1456800.28
# 56      1636263.41
# 57      1553191.63
# 58      1576818.06
# 59      1541102.38
# 60      1495064.75
# 61      1614259.35
# 62      1559889.00
# 63      1564819.81
# 64      1455090.69
# 65      1629391.28
# 66      1604775.58
# 67      1428218.27
# 68      1466046.67
# 69      1635078.41
# 70      1588948.32
# 71      1532114.86
# 72      1438830.15
# 73      1488538.09
# 74      1534849.64
# 75      1455119.97
# 76      1396926.82
# 77      1352219.79
# 78      1624383.75
# 79      1525147.09
# 80      1530761.43
# 81      1464693.46
# 82      1550229.22
#            ...
# 6405     899479.43
# 6406     781970.60
# 6407     776661.74
# 6408     711571.88
# 6409     782300.68
# 6410     770487.37
# 6411     800842.28
# 6412     817741.17
# 6413     837144.63
# 6414     795133.00
# 6415     821498.18
# 6416     822569.16
# 6417     773367.71
# 6418     843361.10
# 6419     749817.08
# 6420     737613.65
# 6421     711671.58
# 6422     725729.51
# 6423     733037.32
# 6424     722496.93
# 6425     718232.26
# 6426     734297.87
# 6427     766512.66
# 6428     702238.27
# 6429     723086.20
# 6430     713173.95
# 6431     733455.07
# 6432     734464.36
# 6433     718125.53
# 6434     760281.43
# Name: Weekly_Sales, dtype: float64

# %%
from sklearn import preprocessing
std_scle=preprocessing.StandardScaler().fit(sales.drop(['Weekly_Sales'],axis=1))
sales_scaled=DataFrame(std_scle.transform(X=sales.drop(['Weekly_Sales'],axis=1),y=['Weekly_Sales']),
         columns=[u'Store',u'Temperature',u'Fuel_Price',u'MarkDown1',u'MarkDown2',u'MarkDown3',u'MarkDown4',u'MarkDown5',u'CPI',
             u'Unemployment',u'Day_of_Month',u'Month',u'DayOfYear',u'WeekOfYear',u'Quarter',u'WeekDay',u'DayCount',
             u'Weekly_Sales_prev_yr',u'Weekly_Sales_prev_yr_1','Weekly_Sales_prev_week'],index=sales.index)

# %%
sales_scaled.head()
# Out:
#        Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
#
# 55  -1.302240   -1.347434 -1.37738        0 -1.635927              1.034348
# 56  -1.228195   -1.273534 -1.37738        0 -1.597434              0.671593
# 57  -1.154151   -1.199635 -1.37738        0 -1.558942              0.931818
#
#     Weekly_Sales_prev_yr_1  Weekly_Sales_prev_week  Weekly_Sales
# 53                1.091569                1.003035    1649614.93
# 54                1.037688                1.080035    1686842.78
# 55                0.674326                1.146722    1456800.28
# 56                0.934987                0.734643    1636263.41
# 57                0.727892                1.056119    1553191.63
#
# [5 rows x 21 columns]

# %%
pred=clf.predict(x)

# %%
pred=DataFrame(pred)

# %% [markdown]
# # Model 2: Linear Regression

# %%
sales.corr()
# Out:
#                                Store  Temperature  Fuel_Price  MarkDown1  \
# Store                   1.000000e+00    -0.030538    0.108294  -0.105893
# Temperature            -3.053776e-02     1.000000    0.253767  -0.103340
# Fuel_Price              1.082944e-01     0.253767    1.000000   0.045301
# MarkDown1              -1.058928e-01    -0.103340    0.045301   1.000000
# MarkDown2              -5.185046e-02    -0.257229   -0.171303   0.145549
# MarkDown3              -3.010791e-02    -0.083964   -0.074137  -0.033616
# MarkDown4              -7.227723e-02    -0.107935   -0.026528   0.833968
# MarkDown5              -3.568899e-02    -0.077821   -0.085493   0.355718
# CPI                    -2.100070e-01     0.188600   -0.394917  -0.016884
# Unemployment            2.257704e-01     0.102120    0.220024  -0.063539
# Day_of_Month            6.030841e-19     0.054924    0.009256   0.081115
# Month                  -2.193033e-19     0.235916   -0.034926  -0.132001
# DayOfYear              -1.864078e-18     0.238257   -0.035255  -0.121343
# WeekOfYear             -1.425472e-18     0.186889   -0.090482  -0.113114
# Quarter                 2.193033e-19     0.238154   -0.033995  -0.120190
# WeekDay                          NaN          NaN         NaN        NaN
# DayCount                3.508853e-18     0.177088    0.167326   0.405565
# Weekly_Sales_prev_yr   -3.336897e-01    -0.063886    0.004080   0.214199
# Weekly_Sales_prev_yr_1 -3.330515e-01    -0.058451    0.021306   0.240724
# Weekly_Sales_prev_week -3.398522e-01    -0.065332   -0.008750   0.226851
# Weekly_Sales           -3.394089e-01    -0.063974   -0.005062   0.241222
#
#                         MarkDown2  MarkDown3  MarkDown4  MarkDown5       CPI  \
# Store                   -0.051850  -0.030108  -0.072277  -0.035689 -0.210007
# Temperature             -0.257229  -0.083964  -0.107935  -0.077821  0.188600
# Fuel_Price              -0.171303  -0.074137  -0.026528  -0.085493 -0.394917
# MarkDown1                0.145549  -0.033616   0.833968   0.355718 -0.016884
# MarkDown2                1.000000  -0.013279   0.091825   0.100826 -0.016299
# MarkDown3               -0.013279   1.000000  -0.023811   0.026370 -0.012513
# MarkDown4                0.091825  -0.023811   1.000000   0.260432 -0.021939
# MarkDown5                0.100826   0.026370   0.260432   1.000000  0.059550
# CPI                     -0.016299  -0.012513  -0.021939   0.059550  1.000000
# Unemployment            -0.022713  -0.008358  -0.050339  -0.088561 -0.266223
# Day_of_Month            -0.024251   0.053464   0.129783  -0.036288  0.000370
# Month                   -0.014571   0.152773  -0.159861   0.080060  0.009109
# DayOfYear               -0.015906   0.157222  -0.145284   0.078457  0.009314
# WeekOfYear               0.124127   0.152773  -0.149099   0.101090  0.010111
# Quarter                 -0.013942   0.150458  -0.133263   0.072052  0.009815
# WeekDay                       NaN        NaN        NaN        NaN       NaN
# DayCount                 0.034739  -0.009935   0.238636   0.353137  0.050937
# Weekly_Sales_prev_yr     0.235741   0.056683   0.148182   0.235320 -0.075856
# Weekly_Sales_prev_yr_1   0.078809   0.080295   0.179206   0.235496 -0.075482
# Weekly_Sales_prev_week   0.238168   0.059905   0.154290   0.257013 -0.068475
# Weekly_Sales             0.103213   0.153734   0.181623   0.231674 -0.069242
#
#                         Unemployment      ...              Month  \
# Store                       0.225770      ...      -2.193033e-19
# Temperature                 0.102120      ...       2.359156e-01
# Fuel_Price                  0.220024      ...      -3.492566e-02
# MarkDown1                  -0.063539      ...      -1.320014e-01
# MarkDown2                  -0.022713      ...      -1.457126e-02
# MarkDown3                  -0.008358      ...       1.527729e-01
# MarkDown4                  -0.050339      ...      -1.598609e-01
# MarkDown5                  -0.088561      ...       8.005976e-02
# CPI                        -0.266223      ...       9.109229e-03
# Unemployment                1.000000      ...      -2.844488e-02
# Day_of_Month                0.003558      ...       9.046183e-03
# Month                      -0.028445      ...       1.000000e+00
# DayOfYear                  -0.028947      ...       9.957365e-01
# WeekOfYear                 -0.034854      ...       9.201021e-01
# Quarter                    -0.036543      ...       9.646710e-01
# WeekDay                          NaN      ...                NaN
# DayCount                   -0.210088      ...       2.504827e-01
# Weekly_Sales_prev_yr       -0.096696      ...       7.188369e-02
# Weekly_Sales_prev_yr_1     -0.100060      ...       5.768159e-02
# Weekly_Sales_prev_week     -0.122067      ...       6.833358e-02
# Weekly_Sales               -0.123456      ...       6.650939e-02
#
#                            DayOfYear    WeekOfYear       Quarter  WeekDay  \
# Store                  -1.864078e-18 -1.425472e-18  2.193033e-19      NaN
# Temperature             2.382570e-01  1.868888e-01  2.381535e-01      NaN
# Fuel_Price             -3.525485e-02 -9.048203e-02 -3.399457e-02      NaN
# MarkDown1              -1.213434e-01 -1.131142e-01 -1.201904e-01      NaN
# MarkDown2              -1.590594e-02  1.241273e-01 -1.394165e-02      NaN
# MarkDown3               1.572216e-01  1.527730e-01  1.504579e-01      NaN
# MarkDown4              -1.452843e-01 -1.490993e-01 -1.332634e-01      NaN
# MarkDown5               7.845717e-02  1.010899e-01  7.205234e-02      NaN
# CPI                     9.314151e-03  1.011051e-02  9.814598e-03      NaN
# Unemployment           -2.894696e-02 -3.485390e-02 -3.654326e-02      NaN
# Day_of_Month            1.009355e-01  2.971587e-02  1.055308e-02      NaN
# Month                   9.957365e-01  9.201021e-01  9.646710e-01      NaN
# DayOfYear               1.000000e+00  9.184663e-01  9.606569e-01      NaN
# WeekOfYear              9.184663e-01  1.000000e+00  8.986999e-01      NaN
# Quarter                 9.606569e-01  8.986999e-01  1.000000e+00      NaN
# WeekDay                          NaN           NaN           NaN      NaN
# DayCount                2.549973e-01  2.631699e-01  2.584659e-01      NaN
# Weekly_Sales_prev_yr    7.101456e-02  6.012346e-02  5.828741e-02      NaN
# Weekly_Sales_prev_yr_1  5.820429e-02  4.795163e-02  4.971490e-02      NaN
# Weekly_Sales_prev_week  6.793550e-02  6.588818e-02  5.694984e-02      NaN
# Weekly_Sales            6.464188e-02  6.076199e-02  5.824620e-02      NaN
#
#                             DayCount  Weekly_Sales_prev_yr  \
# Store                   3.508853e-18             -0.333690
# Temperature             1.770877e-01             -0.063886
# Fuel_Price              1.673255e-01              0.004080
# MarkDown1               4.055649e-01              0.214199
# MarkDown2               3.473937e-02              0.235741
# MarkDown3              -9.934711e-03              0.056683
# MarkDown4               2.386361e-01              0.148182
# MarkDown5               3.531366e-01              0.235320
# CPI                     5.093702e-02             -0.075856
# Unemployment           -2.100876e-01             -0.096696
# Day_of_Month            1.496707e-02             -0.004493
# Month                   2.504827e-01              0.071884
# DayOfYear               2.549973e-01              0.071015
# WeekOfYear              2.631699e-01              0.060123
# Quarter                 2.584659e-01              0.058287
# WeekDay                          NaN                   NaN
# DayCount                1.000000e+00             -0.015334
# Weekly_Sales_prev_yr   -1.533403e-02              1.000000
# Weekly_Sales_prev_yr_1 -1.069663e-02              0.944669
# Weekly_Sales_prev_week  1.338116e-02              0.986433
# Weekly_Sales            1.147338e-02              0.953915
#
#                         Weekly_Sales_prev_yr_1  Weekly_Sales_prev_week  \
# Store                                -0.333052               -0.339852
# Temperature                          -0.058451               -0.065332
# Fuel_Price                            0.021306               -0.008750
# MarkDown1                             0.240724                0.226851
# MarkDown2                             0.078809                0.238168
# MarkDown3                             0.080295                0.059905
# MarkDown4                             0.179206                0.154290
# MarkDown5                             0.235496                0.257013
# CPI                                  -0.075482               -0.068475
# Unemployment                         -0.100060               -0.122067
# Day_of_Month                          0.009957               -0.001378
# Month                                 0.057682                0.068334
# DayOfYear                             0.058204                0.067936
# WeekOfYear                            0.047952                0.065888
# Quarter                               0.049715                0.056950
# WeekDay                                    NaN                     NaN
# DayCount                             -0.010697                0.013381
# Weekly_Sales_prev_yr                  0.944669                0.986433
# Weekly_Sales_prev_yr_1                1.000000                0.943332
# Weekly_Sales_prev_week                0.943332                1.000000
# Weekly_Sales                          0.949421                0.962633
#
#                         Weekly_Sales
# Store                      -0.339409
# Temperature                -0.063974
# Fuel_Price                 -0.005062
# MarkDown1                   0.241222
# MarkDown2                   0.103213
# MarkDown3                   0.153734
# MarkDown4                   0.181623
# MarkDown5                   0.231674
# CPI                        -0.069242
# Unemployment               -0.123456
# Day_of_Month               -0.017394
# Month                       0.066509
# DayOfYear                   0.064642
# WeekOfYear                  0.060762
# Quarter                     0.058246
# WeekDay                          NaN
# DayCount                    0.011473
# Weekly_Sales_prev_yr        0.953915
# Weekly_Sales_prev_yr_1      0.949421
# Weekly_Sales_prev_week      0.962633
# Weekly_Sales                1.000000
#
# [21 rows x 21 columns]

# %%
import statsmodels.api as sm

# %%
x=sales.drop(['Weekly_Sales','Unemployment'],axis=1)
y=sales.Weekly_Sales
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

# %%
model=sm.OLS(y_train,X_train)

# %%
results=model.fit()

# %%
print results.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Weekly_Sales   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     3179.
# Date:                Sun, 27 Mar 2016   Prob (F-statistic):               0.00
# Time:                        17:32:02   Log-Likelihood:                -31601.
# No. Observations:                2430   AIC:                         6.324e+04
# Df Residuals:                    2410   BIC:                         6.336e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Store                   -113.7300    189.730     -0.599      0.549      -485.781   258.321
# Temperature             -406.8095    155.243     -2.620      0.009      -711.232  -102.387
# Fuel_Price             -1.702e+04   1.07e+04     -1.586      0.113     -3.81e+04  4019.378
# MarkDown1                  1.5091      0.670      2.254      0.024         0.196     2.822
# MarkDown2                -11.6216      0.468    -24.856      0.000       -12.538   -10.705
# MarkDown3                  7.4311      0.311     23.897      0.000         6.821     8.041
# MarkDown4                  3.8291      0.875      4.378      0.000         2.114     5.544
# MarkDown5                 -4.7927      0.563     -8.520      0.000        -5.896    -3.690
# CPI                       42.5197     68.040      0.625      0.532       -90.902   175.942
# Unemployment            -633.3457   1348.846     -0.470      0.639     -3278.363  2011.671
# Day_of_Month             334.1388   4344.369      0.077      0.939     -8184.947  8853.225
# Month                   5.666e+04   1.32e+05      0.429      0.668     -2.02e+05  3.16e+05
# DayOfYear              -2539.7987   4338.385     -0.585      0.558      -1.1e+04  5967.552
# WeekOfYear              4239.3869    458.784      9.240      0.000      3339.734  5139.039
# Quarter                 5551.7450   8292.396      0.669      0.503     -1.07e+04  2.18e+04
# WeekDay                -5.778e+06   2.52e+06     -2.290      0.022     -1.07e+07  -8.3e+05
# DayCount                  47.2987     20.528      2.304      0.021         7.044    87.553
# Weekly_Sales_prev_yr       0.0731      0.027      2.738      0.006         0.021     0.125
# Weekly_Sales_prev_yr_1     0.1973      0.015     13.101      0.000         0.168     0.227
# Weekly_Sales_prev_week     0.7233      0.026     27.665      0.000         0.672     0.775
# ==============================================================================
# Omnibus:                      815.701   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24416.941
# Skew:                           0.963   Prob(JB):                         0.00
# Kurtosis:                      18.409   Cond. No.                     2.46e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sales
# Out:
#          Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 53   -1.693979    -1.466349   -2.339686  -0.549967  -0.213342  -0.102795
# 54   -1.693979    -0.283165   -2.254970  -0.549967  -0.213342  -0.102795
# 55   -1.693979     0.029417   -2.181304  -0.549967  -0.213342  -0.102795
# 56   -1.693979    -0.157907   -1.359928  -0.549967  -0.213342  -0.102795
# 57   -1.693979    -0.497571   -0.730084  -0.549967  -0.213342  -0.102795
# 58   -1.693979     0.021518   -0.623268  -0.549967  -0.213342  -0.102795
# 59   -1.693979     0.428325   -0.678518  -0.549967  -0.213342  -0.102795
# 60   -1.693979    -0.181040   -0.490669  -0.549967  -0.213342  -0.102795
# 61   -1.693979     0.308145   -0.129706  -0.549967  -0.213342  -0.102795
# 64    -0.635841   -0.682338 -0.408910        0 -1.289495
# 65    -0.561796   -0.608439 -0.408910        0 -1.251003
# 66    -0.487752   -0.534540 -0.408910        0 -1.212510
# 67    -0.413708   -0.460640 -0.408910        0 -1.174018
# 68    -0.339664   -0.386741 -0.408910        0 -1.135526
# 69    -0.265619   -0.312841 -0.408910        0 -1.097033
# 70    -0.191575   -0.238942 -0.408910        0 -1.058541
# 71    -0.117531   -0.165042 -0.408910        0 -1.020048
# 72    -0.043486   -0.091143 -0.408910        0 -0.981556
# 73     0.030558   -0.017243 -0.408910        0 -0.943064
# 74     0.104602    0.056656  0.559560        0 -0.904571
# 75     0.178647    0.130556  0.559560        0 -0.866079
# 76     0.252691    0.204455  0.559560        0 -0.827586
# 77     0.326735    0.278355  0.559560        0 -0.789094
# 78     0.400779    0.352254  0.559560        0 -0.750602
# 79     0.474824    0.426154  0.559560        0 -0.712109
# 80     0.548868    0.500053  0.559560        0 -0.673617
# 81     0.622912    0.573953  0.559560        0 -0.635125
# 82     0.696957    0.647852  0.559560        0 -0.596632
# ...         ...         ...       ...      ...       ...
# 6405  -0.868551   -0.904037 -0.408910        0  0.596632
# 6406  -0.794507   -0.830137 -0.408910        0  0.635125
# 6407  -0.720463   -0.756238 -0.408910        0  0.673617
# 6408  -0.646419   -0.682338 -0.408910        0  0.712109
# 6409  -0.572374   -0.608439 -0.408910        0  0.750602
# 6410  -0.498330   -0.534540 -0.408910        0  0.789094
# 6411  -0.424286   -0.460640 -0.408910        0  0.827586
# 6412  -0.350241   -0.386741 -0.408910        0  0.866079
# 6413  -0.276197   -0.312841 -0.408910        0  0.904571
# 6414  -0.202153   -0.238942 -0.408910        0  0.943064
# 6415  -0.128108   -0.165042 -0.408910        0  0.981556
# 6416  -0.054064   -0.091143 -0.408910        0  1.020048
# 6417   0.019980   -0.017243 -0.408910        0  1.058541
# 6418   0.094025    0.056656  0.559560        0  1.097033
# 6419   0.168069    0.130556  0.559560        0  1.135526
# 6420   0.242113    0.204455  0.559560        0  1.174018
# 6421   0.316157    0.278355  0.559560        0  1.212510
# 6422   0.390202    0.352254  0.559560        0  1.251003
# 6423   0.464246    0.426154  0.559560        0  1.289495
# 6424   0.538290    0.500053  0.559560        0  1.327988
# 6425   0.612335    0.573953  0.559560        0  1.366480
# 6426   0.686379    0.647852  0.559560        0  1.404972
# 6427   0.760423    0.721752  0.559560        0  1.443465
# 6428   0.834468    0.795651  0.559560        0  1.481957
# 6429   0.908512    0.869550  0.559560        0  1.520450
# 6430   0.982556    0.943450  0.559560        0  1.558942
# 6431   1.056600    1.017349  0.559560        0  1.597434
# 6432   1.130645    1.091249  1.528031        0  1.635927
# 6433   1.204689    1.165148  1.528031        0  1.674419
# 6434   1.278733    1.239048  1.528031        0  1.712912
#
#       Weekly_Sales_prev_yr  Weekly_Sales_prev_yr_1  Weekly_Sales_prev_week  \
# 53                1.091248                1.091569                1.003035
# 54                1.088139                1.037688                1.080035
# 55                1.034348                0.674326                1.146722
# 56                0.671593                0.934987                0.734643
# 57                0.931818                0.727892                1.056119
# 58                0.725069                0.787136                0.907311
# 59                0.784215                0.664808                0.949633
# 60                0.662090                1.007144                0.885655
# 61                1.003855                0.918119                0.803187
# 62                0.914979                0.775534                1.016702
# 63                0.772632                0.641139                0.919308
# 64                0.638461                0.701947                0.928140
# 65                0.699167                1.023291                0.731580
# 66                1.019975                0.826189                1.043808
# 67                0.823202                0.656242                0.999714
# 68                0.653538                0.714468                0.683443
# 69                0.711668                1.044078                0.751206
# 70                1.040727                0.912985                1.053996
# 71                0.909854                0.842417                0.971362
# 72                0.839403                0.697654                0.869555
# 73                0.694882                0.822895                0.702453
# 74                0.819913                0.919297                0.791495
# 75                0.916155                0.744776                0.874454
# 76                0.741925                0.630016                0.731633
# 77                0.627356                0.606518                0.627390
# 78                0.603897                1.026052                0.547306
# 79                1.022731                0.851317                1.034838
# 80                0.848288                0.860018                0.857074
# 81                0.856975                0.745143                0.867131
# 82                0.742291                0.908678                0.748782
# ...                    ...                     ...                     ...
# 6405             -0.579144               -0.483557               -0.482642
# 6406             -0.511420               -0.396669               -0.263697
# 6407             -0.484359               -0.445303               -0.474193
# 6408             -0.397615               -0.402921               -0.483703
# 6409             -0.446168               -0.432138               -0.600299
# 6410             -0.403857               -0.552022               -0.473601
# 6411             -0.433025               -0.389441               -0.494763
# 6412             -0.552709               -0.282054               -0.440388
# 6413             -0.390400               -0.395295               -0.410116
# 6414             -0.283191               -0.401119               -0.375358
# 6415             -0.396244               -0.487884               -0.450615
# 6416             -0.402058               -0.436439               -0.403386
# 6417             -0.488678               -0.477362               -0.401468
# 6418             -0.437319               -0.513804               -0.489603
# 6419             -0.478174               -0.526039               -0.364223
# 6420             -0.514555               -0.592416               -0.531790
# 6421             -0.526770               -0.482251               -0.553650
# 6422             -0.593036               -0.557381               -0.600121
# 6423             -0.483055               -0.578615               -0.574938
# 6424             -0.558059               -0.360109               -0.561848
# 6425             -0.579257               -0.553246               -0.580729
# 6426             -0.361117               -0.517947               -0.588368
# 6427             -0.553931               -0.580403               -0.559590
# 6428             -0.518691               -0.575482               -0.501883
# 6429             -0.581042               -0.602648               -0.617019
# 6430             -0.576130               -0.504799               -0.579673
# 6431             -0.603250               -0.563192               -0.597429
# 6432             -0.505565               -0.472029               -0.561100
# 6433             -0.563860               -0.454048               -0.559292
# 6434             -0.472850               -0.361097               -0.588560
#
#       Weekly_Sales
# 53      1649614.93
# 54      1686842.78
# 55      1456800.28
# 56      1636263.41
# 57      1553191.63
# 58      1576818.06
# 59      1541102.38
# 60      1495064.75
# 61      1614259.35
# 62      1559889.00
# 63      1564819.81
# 64      1455090.69
# 65      1629391.28
# 66      1604775.58
# 67      1428218.27
# 68      1466046.67
# 69      1635078.41
# 70      1588948.32
# 71      1532114.86
# 72      1438830.15
# 73      1488538.09
# 74      1534849.64
# 75      1455119.97
# 76      1396926.82
# 77      1352219.79
# 78      1624383.75
# 79      1525147.09
# 80      1530761.43
# 81      1464693.46
# 82      1550229.22
# ...            ...
# 6405     899479.43
# 6406     781970.60
# 6407     776661.74
# 6408     711571.88
# 6409     782300.68
# 6410     770487.37
# 6411     800842.28
# 6412     817741.17
# 6413     837144.63
# 6414     795133.00
# 6415     821498.18
# 6416     822569.16
# 6417     773367.71
# 6418     843361.10
# 6419     749817.08
# 6420     737613.65
# 6421     711671.58
# 6422     725729.51
# 6423     733037.32
# 6424     722496.93
# 6425     718232.26
# 6426     734297.87
# 6427     766512.66
# 6428     702238.27
# 6429     723086.20
# 6430     713173.95
# 6431     733455.07
# 6432     734464.36
# 6433     718125.53
# 6434     760281.43
#
# [4050 rows x 21 columns]

# %% [markdown]
# # Model 3: Ensemble Model

# %%
# %ls
# Out:
#  Volume in drive C is Windows8_OS
#  Volume Serial Number is 5CA2-A60B
#
#  Directory of C:\Users\raviteja\Desktop\MSBAPM\OPIM 5671-Data Mining and Business Intelligence\Course Project\Merged dataet
#
# 03/28/2016  01:14 AM    <DIR>          .
# 03/28/2016  01:14 AM    <DIR>          ..
# 03/27/2016  01:34 AM    <DIR>          .ipynb_checkpoints
# 03/28/2016  01:14 AM           181,094 Ensemble model dataset.xlsx
# 03/26/2016  09:15 AM           390,749 filter_for_final_ts.xlsx
# 03/27/2016  06:16 PM            25,927 iterate.dat
# 03/28/2016  01:11 AM           582,369 sales.csv
# 03/28/2016  01:11 AM           251,385 WALMART Sales Forecasting Supervised technique.ipynb
# 03/27/2016  07:23 PM         1,337,321 WALMART Sales Forecasting.ipynb
#                6 File(s)      2,768,845 bytes
#                3 Dir(s)  405,788,762,112 bytes free

# %%
ensemble=pd.read_excel('Ensemble model dataset.xlsx')

# %%
ensemble.head()
# Out:
#    Exp_Smoothing        ARIMAX       GBM_Pred  Weekly_Sales
# 0      1649614.9  1621008.8000  1662843.47019    1649614.93
# 1      1686842.8  1624041.6323  1686841.06883    1686842.78
# 2      1456800.3  1620985.9178  1456798.39018    1456800.28
# 3      1636263.4  1591994.4619  1636248.94089    1636263.41
# 4      1553191.6  1570233.1188  1553195.42813    1553191.63

# %%
x=ensemble.drop(['Weekly_Sales'],axis=1)
y=ensemble.Weekly_Sales
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

# %%
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

# %%
params = {'n_estimators': 500, 'max_depth': 10}
clf = ensemble.GradientBoostingRegressor(**params)

# %%
clf.fit(X_train, y_train)
mse = mean_squared_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % mse)
# Out:
# MSE: 2045158429.9873

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
clf.score(X_test, y_test)
# Out:
# 0.9937284281520824

# %%
rmse(clf.predict(x),y)
# Out:
# 28601.807145614657

# %%
plt.figure(figsize=(20,10))
feat_imp = pd.Series(clf.feature_importances_, X_test.columns).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Feature Importances')
plt.ylabel('Feature Importance Score')

# %% [markdown]
# # Model 4: GLM
